# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def jr():
    for _ in range(10):
        print("Junior is a great programmer!")

# %%
jr()
# Out:
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
# Junior is a great programmer!
